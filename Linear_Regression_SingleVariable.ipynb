# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\ASUS\Desktop\DATA ANALYST DATA SCIENCE\premium.csv")

# %%
df
# Out:
#    Age  Premium
# 0   25    18000
# 1   30    32000
# 2   35    40000
# 3   40    47000
# 4   45    55000

# %%
sns.lmplot(x='Age',y='Premium',data=df) #line of best fit the one which has low squared root mean error

# %%
plt.scatter(x="Age",y="Premium",data=df)

# %%
x=df.iloc[:,0]

# %%
y=df.iloc[:,1]

# %%
plt.plot(x,y)

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['Age']],df['Premium'])  #fit() method is used to train the model and the first argument is given in 2D array format
# Out:
# LinearRegression()

# %%
reg.predict([[21]])  #predict() method is used to predict the result on unknown variables
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13480.])

# %%
reg.predict([[50]])
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([65100.])

# %%
reg.coef_   #gives the coefficient of x ki power ,,i.e. y=mx+c , m is the coefficient
# Out:
# array([1780.])

# %%
reg.intercept_ #gives the intercept i.e. y=mx+c ,c is the intercept
# Out:
# -23899.999999999985
